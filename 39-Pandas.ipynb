# %%
#Mengacak Urutan Baris Pada Data Frame
#LeonyCornelia-2373002

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.1.4
# 1.26.4

# %%
#Persiapan Data Frame
n_rows = 6
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 5, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  4  3  1  4  3
# 1  4  4  2  3  3
# 2  4  4  1  1  2
# 3  4  1  2  3  2
# 4  3  3  3  2  4
# 5  1  3  1  2  3

# %%
#Mengacak Urutan Baris Pada Data Frame
df.sample(frac=1.0, random_state=1)
# Out:
#    A  B  C  D  E
# 2  4  4  1  1  2
# 1  4  4  2  3  3
# 4  3  3  3  2  4
# 0  4  3  1  4  3
# 3  4  1  2  3  2
# 5  1  3  1  2  3

# %%
df.sample(frac=1.0, random_state=1).reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  4  4  1  1  2
# 1  4  4  2  3  3
# 2  3  3  3  2  4
# 3  4  3  1  4  3
# 4  4  1  2  3  2
# 5  1  3  1  2  3

# %%
df.sample(frac=1.0, random_state=1).reset_index(drop=False)
# Out:
#    index  A  B  C  D  E
# 0      2  4  4  1  1  2
# 1      1  4  4  2  3  3
# 2      4  3  3  3  2  4
# 3      0  4  3  1  4  3
# 4      3  4  1  2  3  2
# 5      5  1  3  1  2  3
